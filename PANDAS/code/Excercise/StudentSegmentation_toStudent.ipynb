# %% [markdown]
# # Create a notebook “StudentSegmentation_toStudent.ipynb” to cluster students into 3 groups.

# %% [markdown]
# “attend.csv” is a simulated student class attendance on the course “2110426 Data Science and Data Engineering”.
#
# The variable “Week” shows a class attendance on a specific week, where 1, 0.5, and missing refer to attend, late, and absent, consecutively.
#
# The variable “Grade” illustrates to the course grade, where 0 refers to ‘F’ and 4 refers to ‘A’. Follow the instructions below.

# %% [markdown]
# ##  Preprocess the data

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15, 6)

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

from scipy.spatial.distance import cdist
# %matplotlib inline

# %% [markdown]
# Import the file “attend.csv” **(Data Set Link: https://github.com/davidjohnnn/all_datasets/raw/master/bay/attend.csv)**

# %% [markdown]
# For the variable grade, drop any records with missing Grade. For the other variables (Week & GPAX), fill missing with 0

# %% [markdown]
# Create the variable “TotalAttendScore”, which is a summation of attending scores

# %% [markdown]
# Select 3 variables for clustering including TotalAttendScore, GPAX, Grade

# %% [markdown]
# Use MinMaxScaler to adjust the range

# %% [markdown]
# Use commands printSchema() and describe() to view the prepared data. Then, capture the output screen

# %% [markdown]
# ## Find the best k for KMeans with random seed = 12345

# %% [markdown]
# Vary k between 2 to 10, inclusively

# %% [markdown]
# Screen capture the plot of elbow and please choose the best k from your plot

# %% [markdown]
# ## Although the best k can be obtained from the previous question, please use k equal to 3 to simplify the output.

# %% [markdown]
# Create cluster using k = 3 with random seed = 12345

# %% [markdown]
# Print cluster centroids. Note that these centroids are needed to inverse back to the original scale using command inverse_transform() from MinMaxScaler

# %% [markdown]
# Screen capture the inversed centroid
